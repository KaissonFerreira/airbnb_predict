# %% [markdown]
# # 0.0 Entender o Problema

# %% [markdown]
# -- Objetivo do problema:
#
#     -- 1.0 Previsão do primeiro destino que o um novo usuário irá escolher.
#
#     -- Porque?
#
#         -- Qual o tipo do modelo de negócio do Airbnb?
#
#             -- Marketplace (conectar oferta e demanda, e poder ganhar em cima dessa transação).
#
#             -- Oferta (Pessoas oferecem acomodação)
#
#                 -- Tamanho do portifólio
#                 -- Diversidade/densidade de portifólio.
#                 -- Preço médio.
#
#             -- Demanda (Pessoas procurando acomodação)
#
#                 -- Número de usuários
#                 -- LTV (Lifetime Value - Quanto que a pessoa vai gastar com a empresa)
#                 -- CAC (Client Acquisition Cost - Custo por cliente)
#
#                 Gross Revenue (Margem de lucro) = (fee * Número de usuário) - CAC
#                 **FEE => É a diferença entre o preço médio e o valor dado a pessoa que oferece a acomadação.**
#
# -- Proposta da Solução:
#
#     -- Modelo de predição do primeiro destino de um novo usuário. Tipo de entrega:
#
#         -- 1.0. Salvar a predição em tabelas no banco de dados para ser acessada por meio de uma ferramenta de visualização.
#         -- 2.0. Construção de API e acesso por meio dela:
#
#             -- Input: Usuário coloca suas características.
#             -- Output: Mostra as características do usuário e a **predição do destino**.
#
#     -- Ciclos para proposta de solução: 16 Ciclos.

# %% [markdown]
# # Ciclo 01 <font color = 'red'> - End to End </font>

# %% [markdown]
# ## 0.0 Imports

# %%
import pandas   as pd
import numpy    as np

from sklearn import model_selection as ms
from sklearn import preprocessing   as pp
from sklearn import metrics         as m
from scikitplot import metrics      as mt

from keras import models   as ml
from keras import layers   as l

# %% [markdown]
# ### 0.1. Helper Functions

# %% [markdown]
# ### 0.2. Loading Data

# %%
a = r'D:\CDS\Projetos\PA01\airbnb_predict\Source\train_users_2.csv'
df_raw = pd.read_csv(a, low_memory=False)
df_raw.shape
# Out:
# (213451, 16)

# %%
#b = r'D:\CDS\Projetos\PA01\airbnb_predict\Source\sessions.csv'
#df_sessions = pd.read_csv(b,low_memory=True)
#df_sessions.shape

# %%
#df_sessions.sample(2)

# %% [markdown]
# ## 1.0. Data Description

# %%
df1 = df_raw.copy()

# %%
print('Number of rows: {}'.format(df1.shape[0]))
print('Number of collumns: {}'.format(df1.shape[1]))
# Out:
# Number of rows: 213451
# Number of collumns: 16

# %%
df1.head()
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US
# 3       Firefox               other
# 4        Chrome                  US

# %% [markdown]
# ### 1.1 Data type:

# %%
df1.dtypes
# Out:
# id                          object
# date_account_created        object
# timestamp_first_active       int64
# date_first_booking          object
# gender                      object
# age                        float64
# signup_method               object
# signup_flow                  int64
# language                    object
# affiliate_channel           object
# affiliate_provider          object
# first_affiliate_tracked     object
# signup_app                  object
# first_device_type           object
# first_browser               object
# country_destination         object
# dtype: object

# %% [markdown]
# Obs: A coluna date_account_created tem que ser Datetime.

# %% [markdown]
# ### 1.2 NA check:

# %%
df1.isna().sum()
# Out:
# id                              0
# date_account_created            0
# timestamp_first_active          0
# date_first_booking         124543
# gender                          0
# age                         87990
# signup_method                   0
# signup_flow                     0
# language                        0
# affiliate_channel               0
# affiliate_provider              0
# first_affiliate_tracked      6065
# signup_app                      0
# first_device_type               0
# first_browser                   0
# country_destination             0
# dtype: int64

# %%
# Remove missing values
df1 = df1.dropna()
df1.shape
# Out:
# (68171, 16)

# %% [markdown]
# ### 1.3 Change Data Type:

# %%
df1.dtypes
# Out:
# id                          object
# date_account_created        object
# timestamp_first_active       int64
# date_first_booking          object
# gender                      object
# age                        float64
# signup_method               object
# signup_flow                  int64
# language                    object
# affiliate_channel           object
# affiliate_provider          object
# first_affiliate_tracked     object
# signup_app                  object
# first_device_type           object
# first_browser               object
# country_destination         object
# dtype: object

# %%
df1.head()
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
# 6  lsw9q7uk0j           2010-01-02          20100102012558         2010-01-05
# 7  0d01nltbrs           2010-01-03          20100103191905         2010-01-13
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
# 6     FEMALE  46.0         basic            0       en             other
# 7     FEMALE  47.0         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
# 6         craigslist               untracked        Web       Mac Desktop
# 7             direct                     omg        Web       Mac Desktop
#
#   first_browser country_destination
# 2            IE                  US
# 3       Firefox               other
# 4        Chrome                  US
# 6        Safari                  US
# 7        Safari                  US

# %%
# date_account_created
df1['date_account_created'] = pd.to_datetime(df1['date_account_created'])
# timestamp_first_active
df1['timestamp_first_active'] = pd.to_datetime(df1['timestamp_first_active'], format='%Y%m%d%H%M%S')

# date_first_booking
df1['date_first_booking'] = pd.to_datetime(df1['date_first_booking'])
# age
df1['age']=df1['age'].astype(np.int64)

# %%
df1.dtypes
# Out:
# id                                 object
# date_account_created       datetime64[ns]
# timestamp_first_active     datetime64[ns]
# date_first_booking         datetime64[ns]
# gender                             object
# age                                 int64
# signup_method                      object
# signup_flow                         int64
# language                           object
# affiliate_channel                  object
# affiliate_provider                 object
# first_affiliate_tracked            object
# signup_app                         object
# first_device_type                  object
# first_browser                      object
# country_destination                object
# dtype: object

# %% [markdown]
# ### 1.4 Check balanced data:

# %%
# Observando o balanceamento da variável resposta
df1['country_destination'].value_counts(normalize=True)

# Obs: Ao excluir as linhas vazias, foi excluído todo uma classe. (NDF = na)
# Out:
# US       0.708864
# other    0.110854
# FR       0.054085
# IT       0.029763
# GB       0.025935
# ES       0.024864
# CA       0.015696
# DE       0.012454
# NL       0.008801
# AU       0.006366
# PT       0.002318
# Name: country_destination, dtype: float64

# %%
df = df1.copy()

# %% [markdown]
# ## 2.0. Data Filtering

# %% [markdown]
# ### 2.1. Filteringo rows

# %% [markdown]
# ### 2.2. Columns selection

# %% [markdown]
# ## 3.0 Data Preparation

# %%
cols_categoric = ['gender',
                'signup_method',
                'language',
                'affiliate_channel',
                'affiliate_provider',
                'first_affiliate_tracked',
                'signup_app',
                'first_device_type',
                'first_browser']
# dummy variable
df_dummy = pd.get_dummies( df.drop( ['id','country_destination'], axis=1 ) ) # Retirando as variáveis do ID e a variável resposta (target)

#join id and country destination 
df = pd.concat( [df[['id','country_destination']],df_dummy], axis=1 )

# %%
df.head()
# Out:
#            id country_destination date_account_created timestamp_first_active  \
# 2  4ft3gnwmtx                  US           2010-09-28    2009-06-09 23:12:47
# 3  bjjt8pjhuk               other           2011-12-05    2009-10-31 06:01:29
# 4  87mebub9p4                  US           2010-09-14    2009-12-08 06:11:05
# 6  lsw9q7uk0j                  US           2010-01-02    2010-01-02 01:25:58
# 7  0d01nltbrs                  US           2010-01-03    2010-01-03 19:19:05
#
#   date_first_booking  age  signup_flow  gender_-unknown-  gender_FEMALE  \
# 2         2010-08-02   56            3                 0              1
# 3         2012-09-08   42            0                 0              1
# 4         2010-02-18   41            0                 1              0
# 6         2010-01-05   46            0                 0              1
# 7         2010-01-13   47            0                 0              1
#
#    gender_MALE  ...  first_browser_Safari  first_browser_SeaMonkey  \
# 2            0  ...                     0                        0
# 3            0  ...                     0                        0
# 4            0  ...                     0                        0
# 6            0  ...                     1                        0
# 7            0  ...                     1                        0
#
#    first_browser_Silk  first_browser_SiteKiosk  first_browser_SlimBrowser  \
# 2                   0                        0                          0
# 3                   0                        0                          0
# 4                   0                        0                          0
# 6                   0                        0                          0
# 7                   0                        0                          0
#
#    first_browser_Sogou Explorer  first_browser_Stainless  \
# 2                             0                        0
# 3                             0                        0
# 4                             0                        0
# 6                             0                        0
# 7                             0                        0
#
#    first_browser_TenFourFox  first_browser_TheWorld Browser  \
# 2                         0                               0
# 3                         0                               0
# 4                         0                               0
# 6                         0                               0
# 7                         0                               0
#
#    first_browser_Yandex.Browser
# 2                             0
# 3                             0
# 4                             0
# 6                             0
# 7                             0
#
# [5 rows x 117 columns]

# %% [markdown]
# ## 4.0. Feature Selection

# %%
df.sample().T
# Out:
#                                               66563
# id                                       t8hurxfpmu
# country_destination                              US
# date_account_created            2013-03-21 00:00:00
# timestamp_first_active          2013-03-21 22:59:12
# date_first_booking              2013-12-19 00:00:00
# ...                                             ...
# first_browser_Sogou Explorer                      0
# first_browser_Stainless                           0
# first_browser_TenFourFox                          0
# first_browser_TheWorld Browser                    0
# first_browser_Yandex.Browser                      0
#
# [117 rows x 1 columns]

# %%
cols_drop = ['id','date_account_created','timestamp_first_active','date_first_booking'] # Original Dates
df=df.drop(cols_drop,axis=1)
#df.dtypes

# %%
X = df.drop('country_destination', axis=1)
y = df['country_destination'].copy()

# %%
X
# Out:
#         age  signup_flow  gender_-unknown-  gender_FEMALE  gender_MALE  \
# 2        56            3                 0              1            0
# 3        42            0                 0              1            0
# 4        41            0                 1              0            0
# 6        46            0                 0              1            0
# 7        47            0                 0              1            0
# ...     ...          ...               ...            ...          ...
# 213415   55            0                 1              0            0
# 213439   43            0                 0              0            1
# 213441   34            0                 0              1            0
# 213443   36            0                 0              1            0
# 213445   23            0                 0              1            0
#
#         gender_OTHER  signup_method_basic  signup_method_facebook  \
# 2                  0                    1                       0
# 3                  0                    0                       1
# 4                  0                    1                       0
# 6                  0                    1                       0
# 7                  0                    1                       0
# ...              ...                  ...                     ...
# 213415             0                    1                       0
# 213439             0                    1                       0
# 213441             0                    1                       0
# 213443             0                    1                       0
# 213445             0                    1                       0
#
#         signup_method_google  language_ca  ...  first_browser_Safari  \
# 2                          0            0  ...                     0
# 3                          0            0  ...                     0
# 4                          0            0  ...                     0
# 6                          0            0  ...                     1
# 7                          0            0  ...                     1
# ...                      ...          ...  ...                   ...
# 213415                     0            0  ...                     0
# 213439                     0            0  ...                     0
# 213441                     0            0  ...                     0
# 213443                     0            0  ...                     1
# 213445                     0            0  ...                     0
#
#         first_browser_SeaMonkey  first_browser_Silk  first_browser_SiteKiosk  \
# 2                             0                   0                        0
# 3                             0                   0                        0
# 4                             0                   0                        0
# 6                             0                   0                        0
# 7                             0                   0                        0
# ...                         ...                 ...                      ...
# 213415                        0                   0                        0
# 213439                        0                   0                        0
# 213441                        0                   0                        0
# 213443                        0                   0                        0
# 213445                        0                   0                        0
#
#         first_browser_SlimBrowser  first_browser_Sogou Explorer  \
# 2                               0                             0
# 3                               0                             0
# 4                               0                             0
# 6                               0                             0
# 7                               0                             0
# ...                           ...                           ...
# 213415                          0                             0
# 213439                          0                             0
# 213441                          0                             0
# 213443                          0                             0
# 213445                          0                             0
#
#         first_browser_Stainless  first_browser_TenFourFox  \
# 2                             0                         0
# 3                             0                         0
# 4                             0                         0
# 6                             0                         0
# 7                             0                         0
# ...                         ...                       ...
# 213415                        0                         0
# 213439                        0                         0
# 213441                        0                         0
# 213443                        0                         0
# 213445                        0                         0
#
#         first_browser_TheWorld Browser  first_browser_Yandex.Browser
# 2                                    0                             0
# 3                                    0                             0
# 4                                    0                             0
# 6                                    0                             0
# 7                                    0                             0
# ...                                ...                           ...
# 213415                               0                             0
# 213439                               0                             0
# 213441                               0                             0
# 213443                               0                             0
# 213445                               0                             0
#
# [68171 rows x 112 columns]

# %% [markdown]
# ## 5.0. Machine Learning Model - Neural Network MLP

# %%
# Split Dataset into training and test
x_train, x_test, y_train, y_test = ms.train_test_split(
                                                        X,
                                                        y,
                                                        test_size = 0.25,
                                                        random_state=42
                                                        )

# %%
#y_train.values # Tem que transformar em valores numéricos. Utiliza-se o One Hot Encoding

# %%
#y_train.values.reshape(-1,1)

# %%
ohe = pp.OneHotEncoder()
y_ohe = y_train.values.reshape(-1,1)
y_train_nn = ohe.fit_transform(y_ohe).toarray()

# %%
#y_train_nn.shape

# %%
# Model definition
model = ml.Sequential()
model.add( l.Dense (
                100,
                input_dim =x_train.shape[1],
                activation = 'relu' 
                ) ) # Irá adicionar as Layers da rede neural .. Camada de entrada

model.add( l.Dense (
                    11, #11 por causa do número de saídas
                    activation = 'softmax' 
                    )
                    )

# Model compile
model.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])

# train model
model.fit(x_train, y_train_nn, epochs=100)
# Out:
# Epoch 1/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.3511 - accuracy: 0.6986
# Epoch 2/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.2625 - accuracy: 0.7066
# Epoch 3/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.2325 - accuracy: 0.7070: 0s -
# Epoch 4/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.2308 - accuracy: 0.7063
# Epoch 5/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1985 - accuracy: 0.7068
# Epoch 6/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.2026 - accuracy: 0.7069
# Epoch 7/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1778 - accuracy: 0.7069
# Epoch 8/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1738 - accuracy: 0.7069
# Epoch 9/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1600 - accuracy: 0.7069
# Epoch 10/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1538 - accuracy: 0.7069
# Epoch 11/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1457 - accuracy: 0.7071
# Epoch 12/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1426 - accuracy: 0.7072
# Epoch 13/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1381 - accuracy: 0.7076
# Epoch 14/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1362 - accuracy: 0.7076
# Epoch 15/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1354 - accuracy: 0.7079
# Epoch 16/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1340 - accuracy: 0.7079
# Epoch 17/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1321 - accuracy: 0.7080
# Epoch 18/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1313 - accuracy: 0.7080
# Epoch 19/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1304 - accuracy: 0.7080
# Epoch 20/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1292 - accuracy: 0.7081
# Epoch 21/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1290 - accuracy: 0.7080
# Epoch 22/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1280 - accuracy: 0.7081
# Epoch 23/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1268 - accuracy: 0.7082
# Epoch 24/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1266 - accuracy: 0.7080
# Epoch 25/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1273 - accuracy: 0.7081
# Epoch 26/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1239 - accuracy: 0.7082
# Epoch 27/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1237 - accuracy: 0.7082
# Epoch 28/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1233 - accuracy: 0.7083
# Epoch 29/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1228 - accuracy: 0.7083
# Epoch 30/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1217 - accuracy: 0.7083
# Epoch 31/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1213 - accuracy: 0.7083
# Epoch 32/100
# 1598/1598 [==============================] - 3s 2ms/step - loss: 1.1200 - accuracy: 0.7082
# Epoch 33/100
# 1598/1598 [==============================] - 3s 2ms/step - loss: 1.1197 - accuracy: 0.7083
# Epoch 34/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1185 - accuracy: 0.7084: 0s - los
# Epoch 35/100
# 1598/1598 [==============================] - 3s 2ms/step - loss: 1.1198 - accuracy: 0.7084: 1s - loss: 1.1
# Epoch 36/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1182 - accuracy: 0.7085
# Epoch 37/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1178 - accuracy: 0.7086
# Epoch 38/100
# 1598/1598 [==============================] - 3s 2ms/step - loss: 1.1167 - accuracy: 0.7087
# Epoch 39/100
# 1598/1598 [==============================] - 3s 2ms/step - loss: 1.1163 - accuracy: 0.7087
# Epoch 40/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1158 - accuracy: 0.7087
# Epoch 41/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1149 - accuracy: 0.7086
# Epoch 42/100
# 1598/1598 [==============================] - 3s 2ms/step - loss: 1.1145 - accuracy: 0.7088
# Epoch 43/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1151 - accuracy: 0.7086
# Epoch 44/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1143 - accuracy: 0.7088
# Epoch 45/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1159 - accuracy: 0.7086
# Epoch 46/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1131 - accuracy: 0.7087
# Epoch 47/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1123 - accuracy: 0.7088
# Epoch 48/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1118 - accuracy: 0.7089: 0s - loss: 1.1123 - accuracy:
# Epoch 49/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1121 - accuracy: 0.7088
# Epoch 50/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1113 - accuracy: 0.7090
# Epoch 51/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1112 - accuracy: 0.7090
# Epoch 52/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1103 - accuracy: 0.7090
# Epoch 53/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1106 - accuracy: 0.7090: 0s
# Epoch 54/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1095 - accuracy: 0.7090
# Epoch 55/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1095 - accuracy: 0.7091
# Epoch 56/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1097 - accuracy: 0.7091
# Epoch 57/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1086 - accuracy: 0.7090
# Epoch 58/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1082 - accuracy: 0.7089
# Epoch 59/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1084 - accuracy: 0.7088
# Epoch 60/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1081 - accuracy: 0.7093
# Epoch 61/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1073 - accuracy: 0.7094
# Epoch 62/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1078 - accuracy: 0.7093
# Epoch 63/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1066 - accuracy: 0.7093
# Epoch 64/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1067 - accuracy: 0.7090
# Epoch 65/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1065 - accuracy: 0.7094
# Epoch 66/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1071 - accuracy: 0.7092: 0s - los
# Epoch 67/100
# 1598/1598 [==============================] - 2s 2ms/step - loss: 1.1070 - accuracy: 0.7091
# Epoch 68/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1057 - accuracy: 0.7093
# Epoch 69/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1058 - accuracy: 0.7092
# Epoch 70/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1050 - accuracy: 0.7093
# Epoch 71/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1054 - accuracy: 0.7095
# Epoch 72/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1042 - accuracy: 0.7096
# Epoch 73/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1042 - accuracy: 0.7092
# Epoch 74/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1032 - accuracy: 0.7096
# Epoch 75/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1038 - accuracy: 0.7096
# Epoch 76/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1046 - accuracy: 0.7097
# Epoch 77/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1035 - accuracy: 0.7098
# Epoch 78/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1029 - accuracy: 0.7097
# Epoch 79/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1031 - accuracy: 0.7098
# Epoch 80/100
# 1598/1598 [==============================] - 3s 2ms/step - loss: 1.1030 - accuracy: 0.7096: 0s
# Epoch 81/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1018 - accuracy: 0.7098
# Epoch 82/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1017 - accuracy: 0.7097
# Epoch 83/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1020 - accuracy: 0.7095
# Epoch 84/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1016 - accuracy: 0.7099
# Epoch 85/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1009 - accuracy: 0.7098
# Epoch 86/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1011 - accuracy: 0.7099
# Epoch 87/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1015 - accuracy: 0.7100: 0s - loss: 1.1021 - accuracy
# Epoch 88/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1008 - accuracy: 0.7100
# Epoch 89/100
# 1598/1598 [==============================] - 2s 2ms/step - loss: 1.1006 - accuracy: 0.7100
# Epoch 90/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1012 - accuracy: 0.7102
# Epoch 91/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1007 - accuracy: 0.7100
# Epoch 92/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.0998 - accuracy: 0.7100
# Epoch 93/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.1005 - accuracy: 0.7102
# Epoch 94/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.0991 - accuracy: 0.7099
# Epoch 95/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.0990 - accuracy: 0.7101
# Epoch 96/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.0994 - accuracy: 0.7100
# Epoch 97/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.0999 - accuracy: 0.7098
# Epoch 98/100
# 1598/1598 [==============================] - 2s 1ms/step - loss: 1.0990 - accuracy: 0.7102
# Epoch 99/100
# 1598/1598 [==============================] - 3s 2ms/step - loss: 1.0997 - accuracy: 0.7102
# Epoch 100/100
# 1598/1598 [==============================] - 3s 2ms/step - loss: 1.0989 - accuracy: 0.7104

# %% [markdown]
# ## 6.0. NN Performance

# %%
# prediction 
pred_nn = model.predict( x_test )

# %%
# Invert prediction
yhat_nn = ohe.inverse_transform( pred_nn )

# %%
# Prediction prepare
y_test_nn = y_test.to_numpy()
yhat_nn = yhat_nn.reshape(1 , -1 )[0]

# %%
yhat_nn
# Out:
# array(['US', 'US', 'US', ..., 'US', 'US', 'US'], dtype=object)

# %%
# Accuracy
m.accuracy_score( 
                y_test_nn, 
                yhat_nn
                )
# Confusion Matrix
mt.plot_confusion_matrix(
                        y_test_nn,
                        yhat_nn, 
                        normalize=False, 
                        figsize=(12,12)
                        )
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>
